# %% [markdown]
# # Tester

# %%
import numpy as np

#your code/answer

# but this not
print('nothing')

# %%
#your code/answer

# %% [markdown]
# ## Of in een markdown cell
# Waarbij dit weergegeven wordt
# #your code/answer
#
# en deze dan?
# ```{solution} ex-brownian-1
# #your code/answer
# maar dit niet
# ```

# %% [markdown]
# # Tester

# %%
import numpy as np

### begin-solution
# this will be gone
p = np.arange(0,10,1)

### end-solution

# but this not
print('nothing')

# %%
### begin-solution
# deze cel is helemaal leeg.
### end-solution

# %% [markdown]
# # Dichtheid*
#
# Als je een helium los laat, vliegt deze snel omhoog. Als je deze door zou prikken, weet je ook dat de Helium atomen snel aan hoogte winnen. Kunnen we dat effect ook terug zien in een simulatie? Wat als we twee verschillende deeltjes hebben met respectievelijk massa $m_1$ en $m_2$
#
# zwaartekracht en massa verschil (dichtheid) deeltjes
